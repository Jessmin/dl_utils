# %%
from pycocotools.coco import COCO
import numpy as np


data_dir = '/home/zhaohj/Documents/dataset/Table/TableBank/TableBank/Detection'
annFile = f'{data_dir}/annotations/tablebank_latex_test.json'
coco = COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!

# %%
cats = coco.loadCats(coco.getCatIds())
nms = [cat['name']for cat in cats]
nms
# Out:
# ['table']

# %%
imgIds = coco.getImgIds(imgIds=13)

# %%
img = coco.loadImgs(imgIds[np.random.randint(0,len(imgIds))])[0]

# %%
img
# Out:
# {'file_name': '1401.1603_7.jpg',
#  'id': 13,
#  'license': 1,
#  'width': 612,
#  'height': 792}

# %%
import skimage.io as io

# %%
import os
from PIL import Image
src_img = os.path.join(data_dir,f"images/{img['file_name']}")
display(Image.open(src_img))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x792 at 0x7F4548E2CA30>

# %%
# Out:
# 0

# %%
import matplotlib.pyplot as plt
I = io.imread(src_img)
plt.imshow(I)
plt.axis('off')
annIds = coco.getAnnIds(imgIds=img['id'], catIds=0, iscrowd=None)
anns = coco.loadAnns(annIds)
coco.showAnns(anns)
# Out:
# (-0.5, 611.5, 791.5, -0.5)
